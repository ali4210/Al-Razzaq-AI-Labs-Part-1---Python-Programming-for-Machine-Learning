# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.metrics import accuracy_score

# %%
from sklearn.datasets import load_iris
iris = load_iris()
X, y = iris.data, iris.target

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
base_estimator = DecisionTreeClassifier(random_state=42)
bagging_clf = BaggingClassifier(base_estimator=base_estimator, n_estimators=10, random_state=42)
bagging_clf.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 base_estimator = DecisionTreeClassifier(random_state=42)
# ----> 2 bagging_clf = BaggingClassifier(base_estimator=base_estimator, n_estimators=10, random_state=42)
#       3 bagging_clf.fit(X_train, y_train)
#
# TypeError: BaggingClassifier.__init__() got an unexpected keyword argument 'base_estimator'

# %%
y_pred = bagging_clf.predict(X_test)
bagging_accuracy = accuracy_score(y_test, y_pred)
print(f"Bagging Classifier Accuracy: {bagging_accuracy:.2f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 y_pred = bagging_clf.predict(X_test)
#       2 bagging_accuracy = accuracy_score(y_test, y_pred)
#       3 print(f"Bagging Classifier Accuracy: {bagging_accuracy:.2f}")
#
# NameError: name 'bagging_clf' is not defined

# %%
single_tree_clf = DecisionTreeClassifier(random_state=42)
single_tree_clf.fit(X_train, y_train
# Out:
#   Cell In[12], line 2
#     single_tree_clf.fit(X_train, y_train
#                                         ^
# _IncompleteInputError: incomplete input

# %%
y_single_pred = single_tree_clf.predict(X_test)
single_accuracy = accuracy_score(y_test, y_single_pred)
print(f"Single Decision Tree Accuracy: {single_accuracy:.2f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 y_single_pred = single_tree_clf.predict(X_test)
#       2 single_accuracy = accuracy_score(y_test, y_single_pred)
#       3 print(f"Single Decision Tree Accuracy: {single_accuracy:.2f}")
#
# NameError: name 'single_tree_clf' is not defined

# %%
print(f"Improvement in Accuracy: {bagging_accuracy - single_accuracy:.2f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 print(f"Improvement in Accuracy: {bagging_accuracy - single_accuracy:.2f}")
#
# NameError: name 'bagging_accuracy' is not defined
