# %%
import nltk

# %%
from nltk.tokenize import sent_tokenize

sample_text = "Natural Language Processing (NLP) enables computers to understand and communicate in human language. It's an exciting field!"
sentences = sent_tokenize(sample_text)

print(sentences)
# Out:
# ['Natural Language Processing (NLP) enables computers to understand and communicate in human language.', "It's an exciting field!"]

# %%
from nltk.tokenize import word_tokenize

words = word_tokenize(sample_text)
print(words)
# Out:
# ['Natural', 'Language', 'Processing', '(', 'NLP', ')', 'enables', 'computers', 'to', 'understand', 'and', 'communicate', 'in', 'human', 'language', '.', 'It', "'s", 'an', 'exciting', 'field', '!']

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))
filtered_words = [word for word in words if word.lower() not in stop_words]
print(filtered_words)
# Out:
# ['Natural', 'Language', 'Processing', '(', 'NLP', ')', 'enables', 'computers', 'understand', 'communicate', 'human', 'language', '.', "'s", 'exciting', 'field', '!']

# %%
from nltk.stem import PorterStemmer

ps = PorterStemmer()
stemmed_words = [ps.stem(word) for word in filtered_words]
print(stemmed_words)
# Out:
# ['natur', 'languag', 'process', '(', 'nlp', ')', 'enabl', 'comput', 'understand', 'commun', 'human', 'languag', '.', "'s", 'excit', 'field', '!']
