# %%
import numpy as np
from sklearn.base import BaseEstimator, TransformerMixin

class MyCustomTransformer(BaseEstimator, TransformerMixin):
    def __init__(self, parameter=1):
        self.parameter = parameter

    def fit(self, X, y=None):
        # Fit based on input data X, if necessary
        return self

    def transform(self, X):
        # Example transformation: Multiply each element by the parameter
        return X * self.parameter

# %%
def transform(self, X):
    # Example: Add a constant value to each element
    return X + self.parameter

# %%
import pandas as pd

data = {'feature1': [10, 20, 30],
        'feature2': [1, 2, 3]}
X = pd.DataFrame(data)

# %%
from sklearn.pipeline import Pipeline

my_pipeline = Pipeline(steps=[
    ('custom_transform', MyCustomTransformer(parameter=5)),
])

transformed_data = my_pipeline.fit_transform(X)
print(transformed_data)
# Out:
#    feature1  feature2
# 0        50         5
# 1       100        10
# 2       150        15
