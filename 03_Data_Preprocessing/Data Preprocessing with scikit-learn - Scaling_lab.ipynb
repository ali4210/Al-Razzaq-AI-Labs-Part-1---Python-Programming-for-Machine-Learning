# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
# Sample data
data = {'Feature1': [140, 150, 155, 160, 165],
        'Feature2': [200, 210, 215, 220, 225]}

df = pd.DataFrame(data)
print("Original Data:\n", df)
# Out:
# Original Data:
#     Feature1  Feature2
# 0       140       200
# 1       150       210
# 2       155       215
# 3       160       220
# 4       165       225

# %%
# Initialize StandardScaler
scaler = StandardScaler()

# Fit and transform the data
scaled_data = scaler.fit_transform(df)

# Convert the scaled data back into a DataFrame
scaled_df = pd.DataFrame(scaled_data, columns=df.columns)
print("Scaled Data:\n", scaled_df)
# Out:
# Scaled Data:
#     Feature1  Feature2
# 0 -1.627467 -1.627467
# 1 -0.464991 -0.464991
# 2  0.116248  0.116248
# 3  0.697486  0.697486
# 4  1.278724  1.278724

# %%
# Compare original and scaled data statistics
print("Original Data Statistics:\n", df.describe())
print("Scaled Data Statistics:\n", scaled_df.describe())

# Visual comparison (optional)
df.plot(kind='bar', title='Original Data')
scaled_df.plot(kind='bar', title='Scaled Data')
# Out:
# Original Data Statistics:
#           Feature1    Feature2
# count    5.000000    5.000000
# mean   154.000000  214.000000
# std      9.617692    9.617692
# min    140.000000  200.000000
# 25%    150.000000  210.000000
# 50%    155.000000  215.000000
# 75%    160.000000  220.000000
# max    165.000000  225.000000
# Scaled Data Statistics:
#         Feature1  Feature2
# count  5.000000  5.000000
# mean   0.000000  0.000000
# std    1.118034  1.118034
# min   -1.627467 -1.627467
# 25%   -0.464991 -0.464991
# 50%    0.116248  0.116248
# 75%    0.697486  0.697486
# max    1.278724  1.278724
# <Axes: title={'center': 'Scaled Data'}>
