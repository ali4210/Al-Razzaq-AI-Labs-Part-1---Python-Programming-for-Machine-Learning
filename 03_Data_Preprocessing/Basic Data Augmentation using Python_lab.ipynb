# %%
from PIL import Image

image = Image.open('sample_image.jpg')
image.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 from PIL import Image
# ----> 3 image = Image.open('sample_image.jpg')
#       4 image.show()
#
# File ~\PycharmProjects\pythonProject3\.venv\Lib\site-packages\PIL\Image.py:3493, in open(fp, mode, formats)
#    3491 if is_path(fp):
#    3492     filename = os.fspath(fp)
# -> 3493     fp = builtins.open(filename, "rb")
#    3494     exclusive_fp = True
#    3495 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sample_image.jpg'

# %%
rotated_image = image.rotate(90)
rotated_image.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 rotated_image = image.rotate(90)
#       2 rotated_image.show()
#
# NameError: name 'image' is not defined

# %%
flipped_image = image.transpose(Image.FLIP_LEFT_RIGHT)
flipped_image.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 flipped_image = image.transpose(Image.FLIP_LEFT_RIGHT)
#       2 flipped_image.show()
#
# NameError: name 'image' is not defined

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\user\pycharmprojects\pythonproject3\.venv\lib\site-packages (3.9.2)
# Requirement already satisfied: click in c:\users\user\pycharmprojects\pythonproject3\.venv\lib\site-packages (from nltk) (8.3.0)
# Requirement already satisfied: joblib in c:\users\user\pycharmprojects\pythonproject3\.venv\lib\site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\user\pycharmprojects\pythonproject3\.venv\lib\site-packages (from nltk) (2025.11.3)
# Requirement already satisfied: tqdm in c:\users\user\pycharmprojects\pythonproject3\.venv\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\user\pycharmprojects\pythonproject3\.venv\lib\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
text = "Data augmentation is a technique to expand dataset diversity."

# %%
import nltk
from nltk.corpus import wordnet

nltk.download('wordnet')

def synonym_replacement(text, n):
    words = text.split()
    new_words = words.copy()
    for _ in range(n):
        word_to_replace = new_words[n % len(new_words)]
        synonyms = [syn.lemmas()[0].name() for syn in wordnet.synsets(word_to_replace)]
        if synonyms:
            new_words[n % len(new_words)] = synonyms[0]  # Only using the first synonym for simplicity
    return ' '.join(new_words)

new_text = synonym_replacement(text, 2)
print("Augmented Text:", new_text)
# Out:
# Augmented Text: Data augmentation beryllium a technique to expand dataset diversity.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
