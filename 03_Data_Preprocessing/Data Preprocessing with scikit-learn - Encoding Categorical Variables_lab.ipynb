# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
data = {'Category': ['Apple', 'Banana', 'Cherry', 'Apple', 'Cherry', 'Banana']}
df = pd.DataFrame(data)
print(df)
# Out:
#   Category
# 0    Apple
# 1   Banana
# 2   Cherry
# 3    Apple
# 4   Cherry
# 5   Banana

# %%
label_encoder = LabelEncoder()
df['Category_encoded'] = label_encoder.fit_transform(df['Category'])
print(df)
# Out:
#   Category  Category_encoded
# 0    Apple                 0
# 1   Banana                 1
# 2   Cherry                 2
# 3    Apple                 0
# 4   Cherry                 2
# 5   Banana                 1

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
onehot_encoder = OneHotEncoder(sparse=False)
onehot_encoded = onehot_encoder.fit_transform(df[['Category']])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 onehot_encoder = OneHotEncoder(sparse=False)
#       2 onehot_encoded = onehot_encoder.fit_transform(df[['Category']])
#
# TypeError: OneHotEncoder.__init__() got an unexpected keyword argument 'sparse'

# %%
categories = onehot_encoder.get_feature_names_out(['Category'])
df_onehot = pd.DataFrame(onehot_encoded, columns=categories)
print(df_onehot)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 categories = onehot_encoder.get_feature_names_out(['Category'])
#       2 df_onehot = pd.DataFrame(onehot_encoded, columns=categories)
#       3 print(df_onehot)
#
# NameError: name 'onehot_encoder' is not defined

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# %%
categorical_features = ['Category']
categorical_transformer = OneHotEncoder(sparse=False)

preprocessor = ColumnTransformer(
    transformers=[
        ('cat', categorical_transformer, categorical_features)
    ])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 categorical_features = ['Category']
# ----> 2 categorical_transformer = OneHotEncoder(sparse=False)
#       4 preprocessor = ColumnTransformer(
#       5     transformers=[
#       6         ('cat', categorical_transformer, categorical_features)
#       7     ])
#
# TypeError: OneHotEncoder.__init__() got an unexpected keyword argument 'sparse'

# %%
from sklearn.linear_model import LogisticRegression

pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                           ('classifier', LogisticRegression())])

X = df[['Category']]
y = [0, 1, 0, 1, 0, 1]  # Sample target

pipeline.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 3
#       1 from sklearn.linear_model import LogisticRegression
# ----> 3 pipeline = Pipeline(steps=[('preprocessor', preprocessor),
#       4                            ('classifier', LogisticRegression())])
#       6 X = df[['Category']]
#       7 y = [0, 1, 0, 1, 0, 1]  # Sample target
#
# NameError: name 'preprocessor' is not defined
