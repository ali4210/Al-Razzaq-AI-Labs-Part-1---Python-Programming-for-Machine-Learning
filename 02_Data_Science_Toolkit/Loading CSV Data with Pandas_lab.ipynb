# %%
import pandas as pd

# %%
# Replace 'your_file.csv' with your actual file path
df = pd.read_csv('your_file.csv')

# %%
print(df.head())

# %%
print(df.isnull().sum())

# %%
pip install missingno
# Out:
# Collecting missingno
#   Downloading missingno-0.5.2-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: numpy in c:\users\user\pycharmprojects\pythonproject3\.venv\lib\site-packages (from missingno) (2.3.5)
# Requirement already satisfied: matplotlib in c:\users\user\pycharmprojects\pythonproject3\.venv\lib\site-packages (from missingno) (3.10.7)
# Requirement already satisfied: scipy in c:\users\user\pycharmprojects\pythonproject3\.venv\lib\site-packages (from missingno) (1.16.3)
# Collecting seaborn (from missingno)
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\pycharmprojects\pythonproject3\.venv\lib\site-packages (from matplotlib->missingno) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\pycharmprojects\pythonproject3\.venv\lib\site-packages (from matplotlib->missingno) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\pycharmprojects\pythonproject3\.venv\lib\site-packages (from matplotlib->missingno) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\pycharmprojects\pythonproject3\.venv\lib\site-packages (from matplotlib->missingno) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\pycharmprojects\pythonproject3\.venv\lib\site-packages (from matplotlib->missingno) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\user\pycharmprojects\pythonproject3\.venv\lib\site-packages (from matplotlib->missingno) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\user\pycharmprojects\pythonproject3\.venv\lib\site-packages (from matplotlib->missingno) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\pycharmprojects\pythonproject3\.venv\lib\site-packages (from matplotlib->missingno) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\user\pycharmprojects\pythonproject3\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.17.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\user\pycharmprojects\pythonproject3\.venv\lib\site-packages (from seaborn->missingno) (2.3.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\pycharmprojects\pythonproject3\.venv\lib\site-packages (from pandas>=1.2->seaborn->missingno) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\pycharmprojects\pythonproject3\.venv\lib\site-packages (from pandas>=1.2->seaborn->missingno) (2025.2)
# Downloading missingno-0.5.2-py3-none-any.whl (8.7 kB)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn, missingno
#
#    ---------------------------------------- 0/2 [seaborn]
#    ---------------------------------------- 0/2 [seaborn]
#    ---------------------------------------- 0/2 [seaborn]
#    ---------------------------------------- 0/2 [seaborn]
#    ---------------------------------------- 2/2 [missingno]
#
# Successfully installed missingno-0.5.2 seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import missingno as msno
msno.matrix(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 import missingno as msno
# ----> 2 msno.matrix(df)
#
# NameError: name 'df' is not defined
