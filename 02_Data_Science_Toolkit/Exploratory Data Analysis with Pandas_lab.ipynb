# %%
import pandas as pd

# Load a sample dataset
df = pd.read_csv('../sample_data.csv')  # Replace with your actual path

# %%
# Display the first few rows of the dataset
print(df.head())

# Display basic information about the dataset
print(df.info())

# Summary of descriptive statistics
print(df.describe())
# Out:
#    Index                                  Name  \
# 0      1  Compact Printer Air Advanced Digital
# 1      2                                Tablet
# 2      3                  Smart Blender Cooker
# 3      4          Advanced Router Rechargeable
# 4      5          Portable Mouse Monitor Phone
#
#                                          Description  \
# 0      Situation organization these memory much off.
# 1        Discussion loss politics free one thousand.
# 2                                  No situation per.
# 3                    For force gas energy six laugh.
# 4  Feeling back religious however author room sci...
#
#                         Brand            Category  Price Currency  Stock  \
# 0     Garner, Boyle and Flynn  Books & Stationery    265      USD    774
# 1                 Mueller Inc    Shoes & Footwear    502      USD     81
# 2  Lawson, Keller and Winters  Kitchen Appliances    227      USD    726
# 3          Gallagher and Sons  Kitchen Appliances    121      USD    896
# 4                   Irwin LLC      Kids' Clothing      1      USD    925
#
#              EAN        Color        Size  Availability  Internal ID
# 0  2091465262179  ForestGreen       Large     pre_order           56
# 1  5286196620740        Black     8x10 in      in_stock           29
# 2  1282898648918    SlateGray          XS      in_stock           70
# 3  3879177514583    PaleGreen           L  discontinued           31
# 4  9055773261265     SeaShell  100x200 mm  discontinued           10
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Index         100 non-null    int64
#  1   Name          100 non-null    object
#  2   Description   100 non-null    object
#  3   Brand         100 non-null    object
#  4   Category      100 non-null    object
#  5   Price         100 non-null    int64
#  6   Currency      100 non-null    object
#  7   Stock         100 non-null    int64
#  8   EAN           100 non-null    int64
#  9   Color         100 non-null    object
#  10  Size          100 non-null    object
#  11  Availability  100 non-null    object
#  12  Internal ID   100 non-null    int64
# dtypes: int64(5), object(8)
# memory usage: 10.3+ KB
# None
#             Index      Price       Stock           EAN  Internal ID
# count  100.000000  100.00000  100.000000  1.000000e+02   100.000000
# mean    50.500000  451.19000  545.710000  4.876267e+12    49.340000
# std     29.011492  281.60911  266.716863  2.918084e+12    28.078253
# min      1.000000    1.00000   10.000000  5.246382e+08     3.000000
# 25%     25.750000  230.75000  347.500000  2.062323e+12    25.000000
# 50%     50.500000  407.50000  575.500000  4.875720e+12    48.000000
# 75%     75.250000  679.00000  749.250000  7.676943e+12    74.500000
# max    100.000000  999.00000  998.000000  9.921752e+12    99.000000

# %%
# Check for missing values
print(df.isnull().sum())

# Handle missing values (Example: Filling with mean or median)
df.fillna(df.mean(), inplace=True)
# Out:
# Index           0
# Name            0
# Description     0
# Brand           0
# Category        0
# Price           0
# Currency        0
# Stock           0
# EAN             0
# Color           0
# Size            0
# Availability    0
# Internal ID     0
# dtype: int64
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       2 print(df.isnull().sum())
#       4 # Handle missing values (Example: Filling with mean or median)
# ----> 5 df.fillna(df.mean(), inplace=True)
#
# File ~\PycharmProjects\pythonProject3\.venv\Lib\site-packages\pandas\core\frame.py:11720, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11712 @doc(make_doc("mean", ndim=2))
#   11713 def mean(
#   11714     self,
#    (...)  11718     **kwargs,
#   11719 ):
# > 11720     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11721     if isinstance(result, Series):
#   11722         result = result.__finalize__(self, method="mean")
#
# File ~\PycharmProjects\pythonProject3\.venv\Lib\site-packages\pandas\core\generic.py:12485, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12478 def mean(
#   12479     self,
#   12480     axis: Axis | None = 0,
#    (...)  12483     **kwargs,
#   12484 ) -> Series | float:
# > 12485     return self._stat_function(
#   12486         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12487     )
#
# File ~\PycharmProjects\pythonProject3\.venv\Lib\site-packages\pandas\core\generic.py:12442, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12438 nv.validate_func(name, (), kwargs)
#   12440 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12442 return self._reduce(
#   12443     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12444 )
#
# File ~\PycharmProjects\pythonProject3\.venv\Lib\site-packages\pandas\core\frame.py:11589, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   11585     df = df.T
#   11587 # After possibly _get_data and transposing, we are now in the
#   11588 #  simple case where we can use BlockManager.reduce
# > 11589 res = df._mgr.reduce(blk_func)
#   11590 out = df._constructor_from_mgr(res, axes=res.axes).iloc[0]
#   11591 if out_dtype is not None and out.dtype != "boolean":
#
# File ~\PycharmProjects\pythonProject3\.venv\Lib\site-packages\pandas\core\internals\managers.py:1519, in BlockManager.reduce(self, func)
#    1517 res_blocks: list[Block] = []
#    1518 for blk in self.blocks:
# -> 1519     nbs = blk.reduce(func)
#    1520     res_blocks.extend(nbs)
#    1522 index = Index([None])  # placeholder
#
# File ~\PycharmProjects\pythonProject3\.venv\Lib\site-packages\pandas\core\internals\blocks.py:406, in Block.reduce(self, func)
#     400 @final
#     401 def reduce(self, func) -> list[Block]:
#     402     # We will apply the function and reshape the result into a single-row
#     403     #  Block with the same mgr_locs; squeezing will be done at a higher level
#     404     assert self.ndim == 2
# --> 406     result = func(self.values)
#     408     if self.values.ndim == 1:
#     409         res_values = result
#
# File ~\PycharmProjects\pythonProject3\.venv\Lib\site-packages\pandas\core\frame.py:11508, in DataFrame._reduce.<locals>.blk_func(values, axis)
#   11506         return np.array([result])
#   11507 else:
# > 11508     return op(values, axis=axis, skipna=skipna, **kwds)
#
# File ~\PycharmProjects\pythonProject3\.venv\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     145         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File ~\PycharmProjects\pythonProject3\.venv\Lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     401 if datetimelike and mask is None:
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#     407     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File ~\PycharmProjects\pythonProject3\.venv\Lib\site-packages\pandas\core\nanops.py:720, in nanmean(values, axis, skipna, mask)
#     718 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#     723     count = cast(np.ndarray, count)
#
# File ~\PycharmProjects\pythonProject3\.venv\Lib\site-packages\pandas\core\nanops.py:1686, in _ensure_numeric(x)
#    1683 inferred = lib.infer_dtype(x)
#    1684 if inferred in ["string", "mixed"]:
#    1685     # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1686     raise TypeError(f"Could not convert {x} to numeric")
#    1687 try:
#    1688     x = x.astype(np.complex128)
#
# TypeError: Could not convert 
.Small approach possible choose according.Audience bit past central film each.Bit responsibility cover him mean call civil.Throughout special new you view season within.Hot behavior traditional.Word score education thousand high treatment.Subject agree you off.Avoid very final food scene possible.Career for much exist.Chance material himself soldier.Task point seat better.Vote only run modern.Major tell him share allow.Drug interview hotel decide pattern.Around tough popular present sign herself pattern.Occur miss son Democrat happy.Three character traditional maybe.Leg my mother father.Focus that consumer amount half.Might poor animal must protect blue forward.Smile human machine section bank.Organization address section collection church gun consumer do.Heavy threat beautiful material assume piece.Control daughter effect investment piece training nation.Apply out industry must tell.Early century every amount than past.Strategy fund mind rather change.Shoulder cost especially.Remember here kind enjoy source room reflect be.Design price for especially section college over green.Success other institution fear.Much guess have pattern southern true hair miss.Quality yet significant lawyer face field yet realize.Do interesting suggest agreement range admit rule.Explain six firm recent rock skin.Ago floor nice member wait.Much table ground information news senior.Thousand various evidence.Try better loss pretty special.Draw material quickly most.Shoulder red boy away if.Investment everything story buy.Nature notice themselves news.Understand still or summer rule.Final art some push.However public major baby.'
#  'Garner, Boyle and FlynnMueller IncLawson, Keller and WintersGallagher and SonsIrwin LLCBenjamin, Nelson and HancockMccoy, Waters and RoseMorrow and SonsEdwards, Odonnell and ConleyBrennan, Archer and RosalesRusso-WestVazquez and SonsDelgado-BlackwellContreras PLCJuarez, Powell and TravisReid, Chase and BallardBarker-MurphyVazquez-SmithPruitt, Higgins and BarnettBray LLCWang-ValenzuelaCarney LtdGallegos, Osborne and CarpenterDouglas, Thornton and SotoHorn-PopeKhan-ParrishBurton PLCHenry GroupLarson-SpenceBonilla-SpearsLove LLCTerry-OliverMorales, Weaver and FernandezNewman LtdNovak, Archer and WaltonMarshall-DoughertyHays-CunninghamBarnes-GlassMeyers-HessWilliamson PLCMay, Hendrix and RobbinsZimmerman, Barr and DavisLevine, Martin and MccannWerner PLCHuff, Cameron and StephensonSuarez, Riddle and SandersHanson-SchultzMalone, Jacobson and HudsonBarron-LittleBonilla-OconnellDecker and SonsMooney-GonzalesBlake, Weiss and MontgomerySingleton PLCRivas GroupCervantes LtdPace-HodgesMorris LLCSchwartz LtdSexton, Dickerson and BlairStokes IncAli-OliverOdonnell, Boyle and OconnorGill LLCMunoz GroupFrost, Christensen and BurnettBurton, Gross and GilesHester, Love and LynchShepherd, Greene and HouseBarry PLCElliott, Mcfarland and DuranGeorge-DayHull IncFleming IncMahoney-BryanKennedy-GordonOlsen-SawyerLowe, Mosley and RiveraSampson-LeonCastro-MccartyDecker, Montes and LoganWhitney GroupBrooks and SonsKaiser-BanksLewis LtdGalloway and SonsCowan IncNichols, Howe and MillerBlair-RussellChristian-TannerHarrington-ValentineBauer IncJackson GroupWang, Ayala and BowenMaldonado-RitterAtkinson IncShea LtdWest LtdBell, Gamble and BarrettHebert, Hughes and Trujillo'
#  "Books & StationeryShoes & FootwearKitchen AppliancesKitchen AppliancesKids' ClothingSkincareLaptops & ComputersAutomotiveSkincareFitness EquipmentHealth & WellnessCleaning SuppliesCyclingAutomotiveCleaning SuppliesTeam SportsAutomotiveHealth & WellnessCleaning SuppliesSmartphonesWomen's ClothingBedding & BathSkincareGrooming ToolsHealth & WellnessCyclingAutomotiveClothing & ApparelFurnitureKids' ClothingSports & OutdoorsFragrancesSmartphonesKids' ClothingShoes & FootwearWomen's ClothingSmartphonesKids' ClothingSports & OutdoorsHaircareFishing & HuntingOffice SuppliesHome DecorHealth & WellnessFitness EquipmentHealth & WellnessCamping & HikingTeam SportsOffice SuppliesFragrancesFitness EquipmentFragrancesBeauty & Personal CareBedding & BathCameras & AccessoriesOffice SuppliesBooks & StationeryWomen's ClothingMen's ClothingGrooming ToolsMen's ClothingCleaning SuppliesBeauty & Personal CareOffice SuppliesSmartphonesWomen's ClothingHaircareAccessories (Bags, Hats, Belts)Beauty & Personal CareSmartwatchesAutomotiveMakeupHome & KitchenSmartwatchesHome DecorCyclingKids' ClothingBedding & BathHome & KitchenAutomotiveMakeupBooks & StationeryOffice SuppliesBooks & StationeryCamping & HikingWomen's ClothingFragrancesHealth & WellnessSports & OutdoorsLaptops & ComputersKitchen AppliancesCameras & AccessoriesFurnitureCleaning SuppliesHaircareLaptops & ComputersBeauty & Personal CareCleaning SuppliesCamping & HikingBedding & Bath"
#  ''
#  '...'
#  'Large8x10 inXSL100x200 mm30x40 cmS8x10 inMediumExtra LargeExtra LargeMediumLXXL30x40 cm5x7 inXL10x10 cmSXSLMLL5x7 inXXLXL50x70 cmExtra LargeLLSExtra Large8x10 inExtra Large10x10 cm10x10 cm5x7 inXLSmallM12x18 inXL5x7 in10x10 cmExtra LargeLargeSXLXXLExtra Large100x200 mmMedium50x70 cmL50x70 cm8x10 inSmallSmall5x7 inMedium100x200 mm50x70 cmS5x7 in5x7 in12x18 in8x10 inXXL10x10 cmXSM30x40 cmLarge8x10 inXXLMediumSLS8x10 inMediumExtra Large5x7 in50x70 cmSXXL10x10 cmLM8x10 inLargeSmall12x18 in12x18 in8x10 inExtra LargeSmall5x7 inMedium'
#  'pre_orderin_stockin_stockdiscontinueddiscontinuedpre_orderdiscontinuedpre_orderpre_orderdiscontinuedpre_orderpre_orderpre_orderpre_orderpre_orderlimited_stockout_of_stockbackorderlimited_stockbackorderin_stockout_of_stockpre_orderbackorderout_of_stocklimited_stockpre_orderlimited_stockin_stockpre_orderlimited_stockpre_orderlimited_stockout_of_stockdiscontinuedbackorderbackorderdiscontinuedout_of_stockdiscontinuedlimited_stockpre_orderlimited_stockin_stockout_of_stocklimited_stockdiscontinuedlimited_stockdiscontinuedpre_orderin_stockin_stockbackorderin_stockbackorderdiscontinuedbackorderbackorderpre_orderin_stockin_stockbackorderpre_orderpre_orderin_stockout_of_stockin_stockdiscontinuedout_of_stocklimited_stockpre_orderbackorderin_stockout_of_stockbackorderin_stockpre_orderin_stockpre_orderout_of_stockin_stockbackorderbackorderin_stocklimited_stockpre_orderdiscontinuedpre_orderlimited_stockpre_orderin_stockin_stockin_stockbackorderpre_orderlimited_stockbackorderlimited_stocklimited_stocklimited_stock'] to numeric

# %%
# Calculate correlation matrix
correlation_matrix = df.corr()

# Display the correlation matrix
print(correlation_matrix)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Calculate correlation matrix
# ----> 2 correlation_matrix = df.corr()
#       4 # Display the correlation matrix
#       5 print(correlation_matrix)
#
# File ~\PycharmProjects\pythonProject3\.venv\Lib\site-packages\pandas\core\frame.py:11076, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11074 cols = data.columns
#   11075 idx = cols.copy()
# > 11076 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11078 if method == "pearson":
#   11079     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\PycharmProjects\pythonProject3\.venv\Lib\site-packages\pandas\core\frame.py:2002, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    2000 if dtype is not None:
#    2001     dtype = np.dtype(dtype)
# -> 2002 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    2003 if result.dtype is not dtype:
#    2004     result = np.asarray(result, dtype=dtype)
#
# File ~\PycharmProjects\pythonProject3\.venv\Lib\site-packages\pandas\core\internals\managers.py:1713, in BlockManager.as_array(self, dtype, copy, na_value)
#    1711         arr.flags.writeable = False
#    1712 else:
# -> 1713     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1714     # The underlying data was copied within _interleave, so no need
#    1715     # to further copy if copy=True or setting na_value
#    1717 if na_value is lib.no_default:
#
# File ~\PycharmProjects\pythonProject3\.venv\Lib\site-packages\pandas\core\internals\managers.py:1772, in BlockManager._interleave(self, dtype, na_value)
#    1770     else:
#    1771         arr = blk.get_values(dtype)
# -> 1772     result[rl.indexer] = arr
#    1773     itemmask[rl.indexer] = 1
#    1775 if not itemmask.all():
#
# ValueError: could not convert string to float: 'Compact Printer Air Advanced Digital'

# %%
import matplotlib.pyplot as plt

# Histogram for a numerical column
df['column_name'].hist()
plt.title('Distribution of column_name')
plt.xlabel('column_name')
plt.ylabel('Frequency')
plt.show()

# Box Plot for numerical columns
df.boxplot(column=['column1', 'column2'])
plt.title('Boxplot of column1 and column2')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\PycharmProjects\pythonProject3\.venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'column_name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 4
#       1 import matplotlib.pyplot as plt
#       3 # Histogram for a numerical column
# ----> 4 df['column_name'].hist()
#       5 plt.title('Distribution of column_name')
#       6 plt.xlabel('column_name')
#
# File ~\PycharmProjects\pythonProject3\.venv\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~\PycharmProjects\pythonProject3\.venv\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'column_name'
